# %%
from KMeansBase import KMeansBase
from KMeansPP import KMeansPP
from ScalableKMeansPP import ScalableKMeansPP
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

if __name__ == '__main__':
    k = 3
    data = np.random.randn(100000,4)
    #data = np.array([[1.1,2],[1,2],[0.9,1.9],[1,2.1],[4,4],[4,4.1],[4.2,4.3],[4.3,4],[9,9],[8.9,9],[8.7,9.2],[9.1,9]])
    kmeans = KMeansPP(data, k)
    _, _, centroids, min_location = kmeans.cluster()
    # plotting code
    plt.figure()
    plt.subplot(1,3,1)
    colors = iter(cm.rainbow(np.linspace(0, 1, k + 1)))
    for col in range (0,k):
            plt.scatter(data[min_location[:,col] == True, :][:,0], data[min_location[:,col] == True, :][:,1], color=next(colors))

    centroid_leg = plt.scatter(centroids[:,0], centroids[:,1], color=next(colors), marker='x')
    plt.legend([centroid_leg], ['Centroids'], scatterpoints=1, loc='best')

    kmeans = KMeansBase(data, k)
    _, _, centroids, min_location = kmeans.cluster()
    plt.subplot(1,3,2)
    colors = iter(cm.rainbow(np.linspace(0, 1, k + 1)))
    for col in range (0,k):
            plt.scatter(data[min_location[:,col] == True, :][:,0], data[min_location[:,col] == True, :][:,1], color=next(colors))

    centroid_leg = plt.scatter(centroids[:,0], centroids[:,1], color=next(colors), marker='x')
    plt.legend([centroid_leg], ['Centroids'], scatterpoints=1, loc='best')


    kmeans = ScalableKMeansPP(data, k, 2, 2)
    _, _, centroids, min_location = kmeans.cluster()
    plt.subplot(1,3,3)
    colors = iter(cm.rainbow(np.linspace(0, 1, k + 1)))
    for col in range (0,k):
            plt.scatter(data[min_location[:,col] == True, :][:,0], data[min_location[:,col] == True, :][:,1], color=next(colors))

    centroid_leg = plt.scatter(centroids[:,0], centroids[:,1], color=next(colors), marker='x')
    plt.legend([centroid_leg], ['Centroids'], scatterpoints=1, loc='best')

plt.show()
# Out:
# iteration counter:  0
# iteration counter:  1
# iteration counter:  2
# iteration counter:  3
# iteration counter:  4
# iteration counter:  5
# iteration counter:  6
# iteration counter:  7
# iteration counter:  8
# iteration counter:  9
# iteration counter:  10
# iteration counter:  11
# iteration counter:  12
# iteration counter:  13
# iteration counter:  14
# iteration counter:  15
# iteration counter:  16
# iteration counter:  17
# iteration counter:  18
# iteration counter:  19
# iteration counter:  20
# iteration counter:  21
# iteration counter:  22
# iteration counter:  23
# iteration counter:  24
# iteration counter:  25
# iteration counter:  26
# iteration counter:  27
# iteration counter:  28
# iteration counter:  29
# iteration counter:  30
# iteration counter:  31
# iteration counter:  32
# iteration counter:  33
# iteration counter:  34
# iteration counter:  35
# iteration counter:  36
# iteration counter:  37
# iteration counter:  38
# iteration counter:  39
# iteration counter:  40
# iteration counter:  41
# iteration counter:  42
# iteration counter:  43
# iteration counter:  44
# iteration counter:  45
# iteration counter:  46
# iteration counter:  47
# iteration counter:  48
# iteration counter:  49
# iteration counter:  50
# iteration counter:  51
# iteration counter:  52
# iteration counter:  382
# iteration counter:  383
# iteration counter:  384
# iteration counter:  385
# iteration counter:  386
# iteration counter:  387
# iteration counter:  388
# iteration counter:  389
# iteration counter:  390
# iteration counter:  391
# iteration counter:  392
# iteration counter:  393
# iteration counter:  394
# iteration counter:  395
# iteration counter:  396
# iteration counter:  397
# iteration counter:  398
# iteration counter:  399
# iteration counter:  400
# iteration counter:  401
# iteration counter:  402
# iteration counter:  403
# iteration counter:  404
# iteration counter:  405
# iteration counter:  406
# iteration counter:  407
# iteration counter:  408
# iteration counter:  409
# iteration counter:  410
# iteration counter:  411
# iteration counter:  412
# iteration counter:  413
# iteration counter:  414
# iteration counter:  415
# iteration counter:  416
# iteration counter:  417
# iteration counter:  418
# iteration counter:  419
# iteration counter:  420
# iteration counter:  421
# iteration counter:  422
# iteration counter:  423
# iteration counter:  424
# iteration counter:  425
# iteration counter:  426
# iteration counter:  427
# iteration counter:  428
# iteration counter:  429
# iteration counter:  430
# Required  431  iterations to stabilize.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c2c35458f75c> in <module>()
#      34
#      35     kmeans = ScalableKMeansPP(data, k, 2, 2)
# ---> 36     _, _, centroids, min_location = kmeans.cluster()
#      37     plt.subplot(1,3,3)
#      38     colors = iter(cm.rainbow(np.linspace(0, 1, k + 1)))
#
# ~\k-means-parallel-master\ipnb\KMeansBase.py in cluster(self)
#       9
#      10     def cluster(self):
# ---> 11         return self._lloyds_iterations()
#      12
#      13     def _initial_centroids(self):
#
# ~\k-means-parallel-master\ipnb\KMeansBase.py in _lloyds_iterations(self)
#      20     def _lloyds_iterations(self):
#      21         #warnings.simplefilter("error")
# ---> 22         centroids = self._initial_centroids()
#      23         #print('Initial Centroids:', centroids)
#      24
#
# ~\k-means-parallel-master\ipnb\ScalableKMeansPP.py in _initial_centroids(self)
#      41         # cluster these r*l + 1 points with K-Means++ to get K points
#      42         kmeans_pp = KMeansPP(weights, self.k)
# ---> 43         _, _, _, min_locations = kmeans_pp.cluster()
#      44         # calculates the new centroids
#      45         new_centroids = np.empty((self.k, self.data.shape[1]))
#
# ~\k-means-parallel-master\ipnb\KMeansBase.py in cluster(self)
#       9
#      10     def cluster(self):
# ---> 11         return self._lloyds_iterations()
#      12
#      13     def _initial_centroids(self):
#
# ~\k-means-parallel-master\ipnb\KMeansBase.py in _lloyds_iterations(self)
#      20     def _lloyds_iterations(self):
#      21         #warnings.simplefilter("error")
# ---> 22         centroids = self._initial_centroids()
#      23         #print('Initial Centroids:', centroids)
#      24
#
# ~\k-means-parallel-master\ipnb\KMeansPP.py in _initial_centroids(self)
#      23             prob_dist = np.min(distance_arr, axis=1)/j_val
#      24             # select the next centroid using the probability distribution calculated before
# ---> 25             centroids = np.vstack([centroids, self.data[np.random.choice(range(self.data.shape[0]),1, p = prob_dist), :]])
#      26         return centroids
#      27
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1
